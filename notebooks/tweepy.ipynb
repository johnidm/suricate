# %%
import json
import pymongo

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream


consumer_key="uIp9sOygqLV2YodNGEdQ4KQzG"
consumer_secret="UR88YXki9sbYG9sbYir3lxCulNrT7kFTLLRDL5dYt0NsMDqJlw"

access_token="1520322540-D9VmEzIpzySesdeiALSosWru326mgUEhgtYepSF"
access_token_secret="9ei6XjrYqGL4vkmrvfe10yqDtALAIXgWJICulPD8gOP8b"

client = pymongo.MongoClient('192.168.99.100')
db = client.twitter


class StdOutListener(StreamListener):
    def on_data(self, data):
        db.a1.insert_one(json.loads(data))
        print('Read')
        return True

    def on_error(self, status):
        print(status)

if __name__ == '__main__':
    print('Iniciando coleta')
    listener = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    stream = Stream(auth, listener)
    stream.filter(track=['LavaJato'])
# Out:
# Iniciando coleta
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# Read
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in _get_socket_no_auth(self)
#     883                     # Can raise ConnectionFailure.
# --> 884                     sock_info = self.sockets.pop()
#     885             except KeyError:
#
# KeyError: 'pop from an empty set'
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in connect(self)
#     802         try:
# --> 803             sock = _configured_socket(self.address, self.opts)
#     804             if self.handshake:
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in _configured_socket(address, options)
#     704     """
# --> 705     sock = _create_connection(address, options)
#     706     ssl_context = options.ssl_context
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in _create_connection(address, options)
#     688     if err is not None:
# --> 689         raise err
#     690     else:
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in _create_connection(address, options)
#     681                 _set_keepalive_times(sock)
# --> 682             sock.connect(sa)
#     683             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# NetworkTimeout                            Traceback (most recent call last)
# <ipython-input-7-7fe2e6e304f1> in <module>()
#      33
#      34     stream = Stream(auth, listener)
# ---> 35     stream.filter(track=['LavaJato'])
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     292             # call a handler first so that the exception can be logged.
#     293             self.listener.on_exception(exception)
# --> 294             raise exception
#     295
#     296     def _data(self, data):
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     322             next_status_obj = buf.read_len(length)
#     323             if self.running:
# --> 324                 self._data(next_status_obj)
#     325
#     326             # # Note: keep-alive newlines might be inserted before each length value.
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/tweepy/streaming.py in _data(self, data)
#     295
#     296     def _data(self, data):
# --> 297         if self.listener.on_data(data) is False:
#     298             self.running = False
#     299
#
# <ipython-input-7-7fe2e6e304f1> in on_data(self, data)
#      19 class StdOutListener(StreamListener):
#      20     def on_data(self, data):
# ---> 21         db.a1.insert_one(json.loads(data))
#      22         print('Read')
#      23         return True
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation)
#     665         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     666             document["_id"] = ObjectId()
# --> 667         with self._socket_for_writes() as sock_info:
#     668             return InsertOneResult(
#     669                 self._insert(sock_info, document,
#
# /usr/local/var/pyenv/versions/3.6.0/lib/python3.6/contextlib.py in __enter__(self)
#      80     def __enter__(self):
#      81         try:
# ---> 82             return next(self.gen)
#      83         except StopIteration:
#      84             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, selector)
#     868         server = self._get_topology().select_server(selector)
#     869         try:
# --> 870             with server.get_socket(self.__all_credentials) as sock_info:
#     871                 yield sock_info
#     872         except NetworkTimeout:
#
# /usr/local/var/pyenv/versions/3.6.0/lib/python3.6/contextlib.py in __enter__(self)
#      80     def __enter__(self):
#      81         try:
# ---> 82             return next(self.gen)
#      83         except StopIteration:
#      84             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/server.py in get_socket(self, all_credentials, checkout)
#     166     @contextlib.contextmanager
#     167     def get_socket(self, all_credentials, checkout=False):
# --> 168         with self.pool.get_socket(all_credentials, checkout) as sock_info:
#     169             yield sock_info
#     170
#
# /usr/local/var/pyenv/versions/3.6.0/lib/python3.6/contextlib.py in __enter__(self)
#      80     def __enter__(self):
#      81         try:
# ---> 82             return next(self.gen)
#      83         except StopIteration:
#      84             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#     848         # First get a socket, then attempt authentication. Simplifies
#     849         # semaphore management in the face of network errors during auth.
# --> 850         sock_info = self._get_socket_no_auth()
#     851         try:
#     852             sock_info.check_auth(all_credentials)
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in _get_socket_no_auth(self)
#     885             except KeyError:
#     886                 # Can raise ConnectionFailure or CertificateError.
# --> 887                 sock_info = self.connect()
#     888             else:
#     889                 # Can raise ConnectionFailure.
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in connect(self)
#     821             if sock is not None:
#     822                 sock.close()
# --> 823             _raise_connection_failure(self.address, error)
#     824
#     825     @contextlib.contextmanager
#
# /usr/local/var/pyenv/versions/3.6.0/envs/venv-bot-periodicos-capes-ci/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(address, error)
#     257         msg = '%s: %s' % (host, error)
#     258     if isinstance(error, socket.timeout):
# --> 259         raise NetworkTimeout(msg)
#     260     elif isinstance(error, SSLError) and 'timed out' in str(error):
#     261         # CPython 2.6, 2.7, PyPy 2.x, and PyPy3 do not distinguish network
#
# NetworkTimeout: 192.168.99.100:27017: timed out
